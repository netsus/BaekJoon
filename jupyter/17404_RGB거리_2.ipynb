# %% [markdown]
# ### 문제

# %%
! # 시작시간 체크

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 문제 요약
#
#     첫째줄에 집개수 N이 주어집니다. 다음 줄 부터는, 집을 R, G, B로 칠할 때 드는 비용이 주어집니다.
#     집은 빨강, 초록, 파랑중 하나로만 칠해야하며 아래 3가지 규칙을 만족해야 합니다.
#     - 1번 집의 색은 2번, N번 집의 색과 같지 않아야 한다.
#     - N번 집의 색은 N-1번, 1번 집의 색과 같지 않아야 한다.
#     - i(2 ≤ i ≤ N-1)번 집의 색은 i-1, i+1번 집의 색과 같지 않아야 한다.
#     최소 비용을 출력해야합니다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
40+57+13
# Out:
# 110

# %% [markdown]
# 상상 코딩
#
#     dp 테이블에 1번 인덱스에는 첫 번째 규칙을 만족하는 최소 색칠 비용을 저장합니다.
#     3가지 규칙은 주어진 배열을 처음과 끝을 연결하여 원형으로 만들면 3번째 규칙 1개만 만족하면 되는 문제로 바뀝니다.
#     원형으로 만든다는 것은 1번과 N번일때만 예외처리해주면 그대로 쓸 수 있어 보입니다.
#     그렇게 1, 2번의 인덱스에서 최소값은 수동으로 계산해서 넣어줍니다.
#     3번째부터는 1번에서 최소값에 대해, 2,3에서 4가지 경우를 고려해서 최소값을 채워넣습니다.
#     N번일 때는 N-2와 1번을 고려해서 N-1, N을 채우는 것과, N-1, 1을 기준으로 채우는것중 최소값을 구해줍니다.
#     처음 집색깔을 뭐로칠하냐에 따라 3가지 경우 dp를 모두 구한다

# %%
! # 끝 시간 체크

# %% [markdown]
# ### 풀이

# %%
N=int(input())
house_rgb=[list(map(int,input().split())) for _ in range(N)]
ans=I=1e9
for i in range(3):
    dp = [[I,I,I] for _ in range(N)]
    dp[0][i] = house_rgb[0][i]
    for j in range(1,N):
        dp[j][0] = house_rgb[j][0] + min(dp[j-1][1],dp[j-1][2])
        dp[j][1] = house_rgb[j][1] + min(dp[j-1][0],dp[j-1][2])
        dp[j][2] = house_rgb[j][2] + min(dp[j-1][0],dp[j-1][1])
    for k in range(3):
        if i != k:
            ans=min(ans,dp[-1][k])
print(ans)

# %% [markdown]
# ### 주석 달린 풀이

# %%
N=int(input())
house_rgb=[list(map(int,input().split())) for _ in range(N)]

ans=E=1e9
for i in range(3):
    dp=[[E, E, E] for _ in range(N)] # dp가 각 R, G, B로 시작했을 때
    dp[0][i] = house_rgb[0][i] # 처음 집 색칠
    for j in range(1,N): # 2번째 집부터 R, G, B로 색칠했을 때 최소값 갱신
        dp[j][0] = house_rgb[j][0] + min(dp[j-1][1], dp[j-1][2]) # 
        dp[j][1] = house_rgb[j][1] + min(dp[j-1][0], dp[j-1][2])
        dp[j][2] = house_rgb[j][2] + min(dp[j-1][0], dp[j-1][1])
    for c in range(3):
        if i != c: # 첫번째 집과 N번째 집이 다른 경우만 선택
            ans = min(ans,dp[-1][c])
print(ans)

# %% [markdown]
# ### 연습

# %%
N=3
house_rgb=[list(map(int,input().split())) for _ in range(N)]
# Out:
# 26 40 83
# 49 60 57
# 13 89 99

# %%
house_rgb
# Out:
# [[26, 40, 83], [49, 60, 57], [13, 89, 99]]

# %%
ans=E=1e9
for i in range(3):
    dp=[[E, E, E] for _ in range(N)]
    dp[0][i] = house_rgb[0][i]
    for j in range(1,N):
        dp[j][0] = house_rgb[j][0] + min(dp[j-1][1], dp[j-1][2])
        dp[j][1] = house_rgb[j][1] + min(dp[j-1][0], dp[j-1][2])
        dp[j][2] = house_rgb[j][2] + min(dp[j-1][0], dp[j-1][1])
    for j in range(3):
        if i != j:
            ans = min(ans,dp[-1][j])

# %%
ans
# Out:
# 110

# %%
# N=int(input())
# house_rgb=[list(map(int,input().split())) for _ in range(N)]
N=3
house_rgb = [[26, 40, 83], [49, 60, 57], [13, 89, 99]]
ans=I=1e9
for i in range(3):
    dp = [[I,I,I] for _ in range(N)]
    dp[0][i] = house_rgb[0][i]
    for j in range(1,N):
        dp[j][0] = house_rgb[j][0] + min(dp[j-1][1],dp[j-1][2])
        dp[j][1] = house_rgb[j][1] + min(dp[j-1][0],dp[j-1][2])
        dp[j][2] = house_rgb[j][2] + min(dp[j-1][0],dp[j-1][1])
    for k in range(3):
        if i!=k:
            ans=min(ans,dp[-1][k])
print(ans)
# Out:
# 172
# 172
# 110
# 110
# 110
# 110

# %%
dp
# Out:
# [[1000000000.0, 1000000000.0, 83], [132, 143, 1000000057.0], [156, 221, 231]]

# %%
# Out:
# 1000000000.0

# %%
house_rgb[0]
# Out:
# [26, 40, 83]

# %%
dp
# Out:
# [[26, 1000000000.0, 1000000000.0],
#  [1000000000.0, 1000000000.0, 1000000000.0],
#  [1000000000.0, 1000000000.0, 1000000000.0]]
