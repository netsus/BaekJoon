# %% [markdown]
# ### 문제

# %%
! # 시작시간 체크

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 상상 코딩
#
#     유니온 파인드나 최소힙을 생각해봤는데 안될것 같다. 어떻게 풀지 모르겠다.

# %%
! # 끝 시간 체크

# %% [markdown]
# ### 풀이

# %%
from collections import deque
import sys
input=sys.stdin.readline
n,m = map(int,input().split())
graph = [[] for _ in range(n+1)]
inDegree = [0]*(n+1)
que = deque(); ans = []

for _ in range(m):
    a,b = map(int,input().split())
    graph[a].append(b)
    inDegree[b] += 1

for i in range(1,n+1):
    if inDegree[i]==0:
        que.append(i)
        
while que:
    cur = que.popleft()
    ans.append(cur)
    for i in graph[cur]:
        inDegree[i] -= 1
        if inDegree[i] == 0:
            que.append(i)
print(*ans)

# %% [markdown]
# ### 주석 달린 풀이

# %% [markdown]
# ### 연습

# %%
import sys
from collections import deque

# %%
n,m = map(int,input().split())
# Out:
# 4 2

# %%
graph = [[] for _ in range(n+1)]
inDegree = [0 for _ in range(n+1)]
que = deque()
ans=[]

# %%
for i in range(m):
    a,b = map(int,input().split())
    graph[a].append(b)
    inDegree[b]+=1
# Out:
# 4 2
# 3 1

# %%
inDegree
# Out:
# [0, 1, 1, 0, 0]

# %%
for i in range(1, n+1):
    if inDegree[i]==0:
        que.append(i)

# %%
que
# Out:
# deque([3, 4])

# %%
while que:
    tmp = que.popleft()
    ans.append(tmp)
    for i in graph[tmp]:
        inDegree[i]-=1
        if inDegree[i]==0:
            que.append(i)

# %%
print(*ans)
# Out:
# 3 4 1 2
