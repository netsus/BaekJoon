# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 제출 풀이

# %%
N=int(input())
T=[*map(int,input().split())]
T.sort()
answer=0
if len(T)%2:
    answer=T.pop()
for i in range(len(T)//2):
    answer=max(answer,T[i]+T[-i-1])
print(answer)
# Out:
# 2
# 1 1
# 2

# %%
N=5
T=[1,2,3,4,5]

T.sort()

# %%
answer=10000

# %%
if len(T)%2:
    answer=T.pop()

# %%
answer
# Out:
# 5

# %%
for i in range(len(T)//2):
    answer=min(answer,T[i]+T[-i-1])
print(answer)
# Out:
# 8
