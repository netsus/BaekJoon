# %% [markdown]
# ### 문제

# %%
! # 시작시간 체크

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
! # 끝 시간 체크

# %% [markdown]
# ### 내 풀이

# %%
N,M=[*map(int,input().split())]
books=[*map(int,input().split())]

positive_li = []; negative_li = []; last = 0
for b in books:
    last = max(abs(b),last)
    if b>0:
        positive_li.append(b)
    else:
        negative_li.append(abs(b))
positive_li.sort(reverse = 1); negative_li.sort(reverse = 1)

result = 0
for i in range(0, len(positive_li), M):
    result += positive_li[i]*2
for i in range(0, len(negative_li), M):
    result += negative_li[i]*2
print(result-last)
# Out:
# 131

# %% [markdown]
# ### 연습

# %%
N,M=7,2
books=[-37, 2, -6, -39, -29, 11, -28]

# %%
positive_li = []
negative_li = []

# %%
for b in books:
    if b>0:
        positive_li.append(b)
    else:
        negative_li.append(abs(b))

# %%
positive_li.sort(reverse=1)
negative_li.sort(reverse=1)

# %%
positive_li,negative_li
# Out:
# ([11, 2], [39, 37, 29, 28, 6])

# %%
last = max(max(positive_li),max(negative_li))
last
# Out:
# 39

# %%
result=0

# %%
for i in range(0, len(positive_li), M):
    print(positive_li[i:i+M])
    result += positive_li[i]*2
# Out:
# [11, 2]

# %%
for i in range(0, len(negative_li), M):
    print(negative_li[i:i+M])
    result += negative_li[i]*2
# Out:
# [39, 37]
# [29, 28]
# [6]

# %%
result-last
# Out:
# 131
